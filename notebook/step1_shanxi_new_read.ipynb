# %%
import pandas as pd
df=pd.read_parquet("../data/processed/shanxi_new.parquet")
df.tail()
# Out:
#                      price  实时价格  实时在线机组容量(MW)  实时负荷率(%)  非市场化机组出力-日内(MW)  \
# index
# 2025-08-21 22:45:00    NaN   NaN           NaN       NaN              NaN
# 2025-08-21 23:00:00    NaN   NaN           NaN       NaN              NaN
# 2025-08-21 23:15:00    NaN   NaN           NaN       NaN              NaN
# 2025-08-21 23:30:00    NaN   NaN           NaN       NaN              NaN
# 2025-08-21 23:45:00    NaN   NaN           NaN       NaN              NaN
#
#                      联络线计划-日内(MW)  竞价空间-日内(MW)  频率实际值(MW)  实际上旋备用(MW)  \
# index
# 2025-08-21 22:45:00           NaN          NaN        NaN         NaN
# 2025-08-21 23:00:00           NaN          NaN        NaN         NaN
# 2025-08-21 23:15:00           NaN          NaN        NaN         NaN
# 2025-08-21 23:30:00           NaN          NaN        NaN         NaN
# 2025-08-21 23:45:00           NaN          NaN        NaN         NaN
#
#                      实际下旋备用(MW)  ...  日前负荷率(%)  非市场化机组出力-日前(MW)  联络线计划-日前(MW)  \
# ...

# %%
df.columns
# Out:
# Index(['price', '实时价格', '实时在线机组容量(MW)', '实时负荷率(%)', '非市场化机组出力-日内(MW)',
#        '联络线计划-日内(MW)', '竞价空间-日内(MW)', '频率实际值(MW)', '实际上旋备用(MW)', '实际下旋备用(MW)',
#        '省调负荷-日内(MW)', '新能源负荷-日内(MW)', '实时风电(MW)', '实时光伏(MW)', '水电出力值-日内(MW)',
#        '日前在线机组容量(MW)', '日前负荷率(%)', '非市场化机组出力-日前(MW)', '联络线计划-日前(MW)',
#        '竞价空间-日前(MW)', '省调负荷-日前(MW)', '新能源负荷-日前(MW)', '正备用-日前(MW)',
#        '新能源负荷备用-日前(MW)', '日前光伏(MW)', '日前风电(MW)'],
#       dtype='object')

# %%
for i in df.columns:
    print(f"Column: {i}")
    print(df[i].tail())
    print("\n")
# Out:
# Column: price
# index
# 2025-08-21 22:45:00   NaN
# 2025-08-21 23:00:00   NaN
# 2025-08-21 23:15:00   NaN
# 2025-08-21 23:30:00   NaN
# 2025-08-21 23:45:00   NaN
# Name: price, dtype: float64
#
#
# Column: 实时价格
# index
# 2025-08-21 22:45:00   NaN
# 2025-08-21 23:00:00   NaN
# 2025-08-21 23:15:00   NaN
# 2025-08-21 23:30:00   NaN
# 2025-08-21 23:45:00   NaN
# Name: 实时价格, dtype: float64
#
#
# Column: 实时在线机组容量(MW)
# index
# 2025-08-21 22:45:00   NaN
# 2025-08-21 23:00:00   NaN
# 2025-08-21 23:15:00   NaN
# 2025-08-21 23:30:00   NaN
# 2025-08-21 23:45:00   NaN
# Name: 实时在线机组容量(MW), dtype: float64
#
#
# Column: 实时负荷率(%)
# index
# 2025-08-21 22:45:00   NaN
# 2025-08-21 23:00:00   NaN
# 2025-08-21 23:15:00   NaN
# 2025-08-21 23:30:00   NaN
# 2025-08-21 23:45:00   NaN
# Name: 实时负荷率(%), dtype: float64
#
#
# Column: 非市场化机组出力-日内(MW)
# index
# 2025-08-21 22:45:00   NaN
# 2025-08-21 23:00:00   NaN
# 2025-08-21 23:15:00   NaN
# 2025-08-21 23:30:00   NaN
# 2025-08-21 23:45:00   NaN
# ...
